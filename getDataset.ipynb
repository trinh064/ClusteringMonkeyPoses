# %% [markdown]
# <a href="https://colab.research.google.com/github/trinh064/ClusteringMonkeyPoses/blob/main/getDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U --no-cache-dir gdown --pre
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1r1AzBoPOka-P9VblP2zhIDe5q7XFadUH&export=download
# To: /content/val.zip
# 100% 2.62G/2.62G [01:15<00:00, 34.8MB/s]

# %%
#Download data
# !gdown "https://drive.google.com/u/0/uc?id=1r1AzBoPOka-P9VblP2zhIDe5q7XFadUH&export=download"
# !gdown "https://drive.google.com/u/0/uc?id=1fudp400JqtQAlxrBNTaw8M9yvsXqd-Yv&export=download"

# %%
#Download annotation
# !gdown "https://drive.google.com/u/0/uc?id=1gSm_sMMmNsoujj34dNagsKcHmgPv-PHe&export=download"
# !gdown "https://drive.google.com/u/0/uc?id=1mZeDieDJojPUKZWco-6Zv4PcrVpyYp1M&export=download"
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1gSm_sMMmNsoujj34dNagsKcHmgPv-PHe&export=download
# To: /content/val2017.json
# 100% 7.69M/7.69M [00:00<00:00, 16.5MB/s]
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1mZeDieDJojPUKZWco-6Zv4PcrVpyYp1M&export=download
# To: /content/train2017.json
# 100% 23.1M/23.1M [00:01<00:00, 21.3MB/s]

# %%
# !mkdir -p data/coco/images
# !unzip train.zip -d data/coco/images/
# !unzip val.zip -d data/coco/images/
# Out:
# Archive:  val.zip
#   inflating: data/coco/images/val/val_0000000.jpg
#   inflating: data/coco/images/val/val_0000001.jpg
#   inflating: data/coco/images/val/val_0000002.jpg
#   inflating: data/coco/images/val/val_0000003.jpg
#   inflating: data/coco/images/val/val_0000004.jpg
#   inflating: data/coco/images/val/val_0000005.jpg
#   inflating: data/coco/images/val/val_0000006.jpg
#   inflating: data/coco/images/val/val_0000007.jpg
#   inflating: data/coco/images/val/val_0000008.jpg
#   inflating: data/coco/images/val/val_0000009.jpg
#   inflating: data/coco/images/val/val_0000010.jpg
#   inflating: data/coco/images/val/val_0000011.jpg
#   inflating: data/coco/images/val/val_0000012.jpg
#   inflating: data/coco/images/val/val_0000013.jpg
#   inflating: data/coco/images/val/val_0000014.jpg
#   inflating: data/coco/images/val/val_0000015.jpg
#   inflating: data/coco/images/val/val_0000016.jpg
#   inflating: data/coco/images/val/val_0000017.jpg
# ...
